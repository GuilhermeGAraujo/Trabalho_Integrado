# %%
import pandas as pd
import missingno as msno

# %%
df =pd.read_csv('test_timeseries\\test_timeseries.csv')
df.head(10)
# Out:
#    fips        date  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  1001  2019-01-01     2.25  100.51  9.69  14.71   13.55   13.52    17.38
# 1  1001  2019-01-02     4.94  100.48  8.65  13.05   11.83   11.74    17.76
# 2  1001  2019-01-03    20.74  100.03  8.59  12.12   11.67   11.67    13.74
# 3  1001  2019-01-04    16.17   99.47  7.93  11.80   10.38    9.59    18.19
# 4  1001  2019-01-05     0.01  100.39  5.32   7.91    4.73    4.71    14.37
# 5  1001  2019-01-06     0.00  100.69  5.76  10.26    5.94    5.82    18.38
# 6  1001  2019-01-07     0.01  100.65  7.03  11.03    8.78    8.67    18.42
# 7  1001  2019-01-08     0.05  100.57  8.75  13.15   12.01   11.98    20.04
# 8  1001  2019-01-09     0.00  100.90  4.55   6.51    2.60    2.36    11.30
# 9  1001  2019-01-10     0.00  100.92  3.30   2.53   -1.82   -1.83     9.17
#
#    T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# ...

# %%
df.shape
# Out:
# (2271948, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2271948 entries, 0 to 2271947
# Data columns (total 21 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fips         int64
#  1   date         object
#  2   PRECTOT      float64
#  3   PS           float64
#  4   QV2M         float64
#  5   T2M          float64
#  6   T2MDEW       float64
#  7   T2MWET       float64
#  8   T2M_MAX      float64
#  9   T2M_MIN      float64
#  10  T2M_RANGE    float64
#  11  TS           float64
#  12  WS10M        float64
#  13  WS10M_MAX    float64
#  14  WS10M_MIN    float64
#  15  WS10M_RANGE  float64
#  16  WS50M        float64
#  17  WS50M_MAX    float64
#  18  WS50M_MIN    float64
#  19  WS50M_RANGE  float64
#  20  score        float64
# dtypes: float64(19), int64(1), object(1)
# memory usage: 364.0+ MB

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Único dado faltando é quanto ao score (essa é váriavel que queremos predizer a nota quanto à seca), isso é devido ao fato da avaliação do nível de seca ser publicada semanalmente, mas os dados de clima diaramente.

# %%
#fips é uma váriavel categórica para identificação da área(terreno)
df.fips=df.fips.astype('object')

# %%
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'g')))
# Out:
#            PRECTOT           PS         QV2M          T2M       T2MDEW  \
# count  2.27195e+06  2.27195e+06  2.27195e+06  2.27195e+06  2.27195e+06
# mean       2.93885      96.6617      8.22326      12.9457      7.78254
# std        6.71911      5.44329      4.92527      10.8594      10.3332
# min              0        66.75          0.1       -38.57       -41.54
# 25%              0        95.86         3.96         4.53        -0.16
# 50%           0.21         98.3         7.06        13.89         8.25
# 75%           2.54        99.96        12.22        22.23        16.85
# max         249.34       103.88        22.52        40.33        27.05
#
#             T2MWET      T2M_MAX      T2M_MIN    T2M_RANGE           TS  \
# count  2.27195e+06  2.27195e+06  2.27195e+06  2.27195e+06  2.27195e+06
# mean       7.79308      18.6122      7.73715      10.8751      12.9816
# std        10.1045      11.4039      10.6321      3.85062      11.0635
# ...

# %% [markdown]
# Aparentemente não há nenhum valor incoerente, unicos negativos são temperatura e não ennum valor extramamente alto ou baixo para pressã o e velocidade do vento

# %%
df.plot(subplots=True,figsize=(20,30))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
